# %% [markdown]
# <a href="https://colab.research.google.com/github/GitH-Mukul/Projects/blob/main/TODO_List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

def add_task(tasks):
    """Adds a task to the to-do list."""
    task = input("Enter the task: ")
    tasks.append(task)
    print(f"Task '{task}' added.")

def view_tasks(tasks):
    """Displays the to-do list."""
    if not tasks:
        print("No tasks in the to-do list.")
    else:
        print("To-Do List:")
        for index, task in enumerate(tasks):
            print(f"{index + 1}. {task}")

def remove_task(tasks):
    """Removes a task from the to-do list."""
    view_tasks(tasks)
    if not tasks:
        return

    try:
        index = int(input("Enter the task number to remove: ")) - 1
        if 0 <= index < len(tasks):
            removed_task = tasks.pop(index)
            print(f"Task '{removed_task}' removed.")
        else:
            print("Invalid task number.")
    except ValueError:
        print("Invalid input. Please enter a number.")

def save_tasks(tasks, filename="todo.txt"):
    """Saves the to-do list to a file."""
    try:
        with open(filename, "w") as file:
            for task in tasks:
                file.write(task + "\n")
        print(f"Tasks saved to '{filename}'.")
    except Exception as e:
        print(f"Error saving tasks: {e}")

def load_tasks(filename="todo.txt"):
    """Loads the to-do list from a file."""
    tasks = []
    if os.path.exists(filename):
        try:
            with open(filename, "r") as file:
                tasks = [line.strip() for line in file.readlines()]
            print(f"Tasks loaded from '{filename}'.")
        except Exception as e:
            print(f"Error loading tasks: {e}")
    return tasks

def main():
    """Main function to run the to-do list application."""
    tasks = load_tasks()

    while True:
        print("\nTo-Do Notes Builder")
        print("1. Add Task")
        print("2. View Tasks")
        print("3. Remove Task")
        print("4. Save Tasks")
        print("5. Exit")

        choice = input("Enter your choice: ")

        if choice == "1":
            add_task(tasks)
        elif choice == "2":
            view_tasks(tasks)
        elif choice == "3":
            remove_task(tasks)
        elif choice == "4":
            save_tasks(tasks)
        elif choice == "5":
            print("Exiting...")
            break
        else:
            print("Invalid choice. Please try again.")

if __name__ == "__main__":
    main()
# Out:
# To-Do Notes Builder
# 1. Add Task
# 2. View Tasks
# 3. Remove Task
# 4. Save Tasks
# 5. Exit
# Enter your choice: 1
# Enter the task: go to the gym
# Task 'go to the gym' added.
#
# To-Do Notes Builder
# 1. Add Task
# 2. View Tasks
# 3. Remove Task
# 4. Save Tasks
# 5. Exit
# Enter your choice: 2
# To-Do List:
# 1. go to the gym
#
# To-Do Notes Builder
# 1. Add Task
# 2. View Tasks
# 3. Remove Task
# 4. Save Tasks
# 5. Exit
# Enter your choice: 4
# Tasks saved to 'todo.txt'.
#
# To-Do Notes Builder
# 1. Add Task
# 2. View Tasks
# 3. Remove Task
# 4. Save Tasks
# 5. Exit
# Enter your choice: 5
# Exiting...
